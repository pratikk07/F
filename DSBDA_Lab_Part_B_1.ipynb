# %%
import pandas as pd
import numpy as np
import io
  
df = pd.read_csv('dataset_Facebook.csv',sep = ';')
#print(df)

df.head(5) # print first 5 entries of dataset
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
print("Shape of Dataframe:",np.shape(df)) #shape of Dataframe
# Out:
# Shape of Dataframe: (500, 19)

# %%
# print info of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
# describe dataframe
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
# accessing type columns of dataframe  i.e creating subset

video_sub=df['Type']
video_sub
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
print(df.columns)  #print all columns of dataframe
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df[['Type','Category']] # accessing type and category columns
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
# craeting subset of dataframe

Bydf_subset = df[['like','share']]

print(Bydf_subset)
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
#likes greater than 100
Hydf_subset1 = df[df['like']>100]

print(Hydf_subset1)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 491             85979   Photo         3           1             6          3
# 492             85979    Link         1           1             5         11
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
#
# ...

# %%
df.loc[:2,:]  # Access a group of rows and columns i.e 0,1,2 rows and all columns
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
#
# ...

# %%
df.loc[[1,5,7]] # Accessing 1,5,7 rows of dataframe
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 5            139441  Status         2          12             1          9
# 7            139441   Photo         3          12             7          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 5   0.0                      10472                            20849
# 7   1.0                      13720                            24137
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 1                    1457                     1361
# 5                    1191                     1073
# 7                     537                      232
#
#    Lifetime Post Consumptions  \
# 1                        1674
# 5                        1389
# 7                         305
#
# ...

# %%
df.loc[1:7,['like','share']] # Accessing 1-7 rows and 2 columns
# Out:
#      like  share
# 1   130.0   29.0
# 2    66.0   14.0
# 3  1572.0  147.0
# 4   325.0   49.0
# 5   152.0   33.0
# 6   249.0   27.0
# 7   325.0   14.0

# %%
 #sort values by descending order of 'like' column. because ascending is False.
    
df.sort_values(by = "like",ascending= False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df.sort_values("like") # sorting in ascending order of 'like' column
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df.sort_values(by = "like",ascending= False, kind="mergesort")
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df.sort_values(by=["like", "share"])
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
# transpose is used to convert shape of dataframe, 
# i.e intial shape was (500 rows X 19 columns) after transpose it becomes (19 rows X 500 columns)

df_transpose = np.transpose(df)
print(df_transpose)
print("Shape of df_transpose",np.shape(df_transposetranspose))
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                     0       0       0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
print("intial shape of dataframe: ",np.shape(df))
print("After transpose shape becomes:",np.shape(df_transpose))
# Out:
# intial shape of dataframe:  (500, 19)
# After transpose shape becomes: (19, 500)

# %%
# Select specific columns of dataframe
selective_df = pd.DataFrame(df,columns =['like','share','Category','Type'])

selective_df.head(5)
# Out:
#      like  share  Category    Type
# 0    79.0   17.0         2   Photo
# 1   130.0   29.0         2  Status
# 2    66.0   14.0         3   Photo
# 3  1572.0  147.0         2   Photo
# 4   325.0   49.0         2   Photo

# %%
pivot_table = pd.pivot_table(selective_df,index= ['Category','like'])

print(pivot_table)
# Out:
#                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]

# %%
pivot_table.shape
# Out:
# (368, 1)

# %%
pivot_table.reset_index(inplace=True)

pivot_table
# Out:
#      Category    like       share
# 0           1     0.0    0.000000
# 1           1     1.0    2.000000
# 2           1     2.0    0.000000
# 3           1     3.0    0.666667
# 4           1     4.0    1.000000
# ..        ...     ...         ...
# 363         3  1155.0  102.000000
# 364         3  1372.0   47.000000
# 365         3  1546.0  181.000000
# 366         3  1639.0  122.000000
# 367         3  1998.0  128.000000
#
# [368 rows x 3 columns]

# %%
# The melt() function is used to convert a data frame with several measurement columns into a data frame 
# in this canonical format, which has one row for every observed (measured) value.

pivot_table.melt(id_vars=['like','share'])
# Out:
#        like       share  variable  value
# 0       0.0    0.000000  Category      1
# 1       1.0    2.000000  Category      1
# 2       2.0    0.000000  Category      1
# 3       3.0    0.666667  Category      1
# 4       4.0    1.000000  Category      1
# ..      ...         ...       ...    ...
# 363  1155.0  102.000000  Category      3
# 364  1372.0   47.000000  Category      3
# 365  1546.0  181.000000  Category      3
# 366  1639.0  122.000000  Category      3
# 367  1998.0  128.000000  Category      3
#
# [368 rows x 4 columns]

# %%
# Merging two dataframe into one dataframe

data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 


data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 

df = pd.DataFrame(data1,index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
frames = [df, df1]
res1 = pd.concat(frames)  # Merging dataframe using concat method
res1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
df_new = pd.DataFrame(data1,index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 

print(df, "\n\n", df1) 


res2 = pd.concat([df, df1], axis=0, join='inner')


res2
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 2    Abhi   17     Nagpur         Btech
# 3  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 2    Abhi   17     Nagpur         Btech
# 3  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
# Define a dictionary containing employee data 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
   
# Define a dictionary containing employee data 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1)
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2) 
  
 
print(df, "\n\n", df1) 

res = pd.merge(df, df1, on='key')
res
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#
#    key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
# Define a dictionary containing employee data 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
   
# Define a dictionary containing employee data 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1)
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2) 
  
 
print(df, "\n\n", df1) 

# merging dataframe using multiple keys
res1 = pd.merge(df, df1, on=['key', 'key1'])
 
res1
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom
